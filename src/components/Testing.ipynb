# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.pipeline import Pipeline

import warnings
warnings.filterwarnings('ignore')

############################################## PREPROCESSING ##############################################
from sklearn.preprocessing import MinMaxScaler

################################################# METRICS #################################################
from sklearn.metrics import f1_score


import joblib

# %%
X_test, y_test = joblib.load(r"C:\Users\pedro\OneDrive\Desktop\DSProject Folder\src\testing_data\test_data.pkl")

# %%
gb = joblib.load(r"C:\Users\pedro\OneDrive\Desktop\DSProject Folder\src\models\final_model_gb.pkl")
lr = joblib.load(r"C:\Users\pedro\OneDrive\Desktop\DSProject Folder\src\models\final_model_lr.pkl")

# %%
scaler= joblib.load(r"C:\Users\pedro\OneDrive\Desktop\DSProject Folder\src\components\scaler.pkl")

# %%
X_test
# Out:
#        Effect of forex changes on cash  SG&A Expenses Growth  \
# 5604                      0.000000e+00               0.50320
# 9595                      0.000000e+00              -0.11280
# 10719                    -1.092000e+08               0.45358
# 2813                      0.000000e+00               0.00000
# 3070                     -3.590000e+05               0.82890
# ...                                ...                   ...
# 14142                     0.000000e+00               0.06770
# 10336                    -3.160000e+06               0.03534
# 893                       0.000000e+00               0.25980
# 14208                     9.885983e+07               0.06880
# 4160                      0.000000e+00               2.71310
#
#        Receivables Turnover  5Y Revenue Growth (per Share)  \
# 5604                5.05070                        0.13996
# 9595                4.15280                       -0.10530
# ...

# %%
X_test_scaled = scaler.transform(X_test)

# %%
y_pred_gb = gb.predict(X_test_scaled)
f1_gb = f1_score(y_test, y_pred_gb, average='weighted')
print(f"Gradient Boosting F1 Score on Test Set: {f1_gb:.3f}")
# Out:
# Gradient Boosting F1 Score on Test Set: 0.560

# %%
y_pred_lr = lr.predict(X_test_scaled)
f1_lr = f1_score(y_test, y_pred_lr, average='weighted')
print(f"Logistic Regression F1 Score on Test Set: {f1_lr:.3f}")
# Out:
# Logistic Regression F1 Score on Test Set: 0.512
